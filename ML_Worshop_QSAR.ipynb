# %% [markdown]
# <a href="https://colab.research.google.com/github/ENSB-Projects/ML-Workshop-QSAR/blob/main/ML_Worshop_QSAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) Data Collection

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.1) Search ChEMBL Database

# %% [markdown]
# ### 1.1.1) Install ChEMBL Library

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.3.2-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.5.20)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (26.1.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-26.1.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.10.0)
# Collecting url-normalize>=2.0 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-3.0.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 3.3 MB/s eta 0:00:00
# Downloading requests_cache-1.3.2-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 6.6 MB/s eta 0:00:00
# Downloading cattrs-26.1.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.6 MB/s eta 0:00:00
# Downloading url_normalize-3.0.0-py3-none-any.whl (16 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-26.1.0 chembl_webresource_client-0.10.9 requests-cache-1.3.2 url-normalize-3.0.0

# %% [markdown]
# ### 1.1.2) Import ChEMBL Library

# %%
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### 1.1.3) Search for Target Protein

# %%
target = new_client.target
target_query = target.search('aromatase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references           organism  \
# 0               []       Homo sapiens
# 1               []  Rattus norvegicus
# 2               []       Homo sapiens
#
#                                            pref_name  score  \
# 0                                          Aromatase   20.0
# 1                                          Aromatase   19.0
# 2  von Hippel-Lindau disease tumor suppressor/Aro...   16.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL1978
# 1               False       CHEMBL3859
# 2               False    CHEMBL6066122
#
#                                    target_components  \
# 0  [{'accession': 'P11511', 'component_descriptio...
# 1  [{'accession': 'P22443', 'component_descriptio...
# 2  [{'accession': 'P11511', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN    9606
# 1               SINGLE PROTEIN   10116
# 2  PROTEIN-PROTEIN INTERACTION    9606

# %%
selected_target = targets['target_chembl_id'][0]
selected_target
# Out:
# 'CHEMBL1978'

# %% [markdown]
# ### 1.1.4) Get Target Bioactivities

# %%
activity = new_client.activity
Results = activity.filter(target_chembl_id = selected_target).filter(standard_type = 'IC50')

# %%
data = pd.DataFrame.from_dict(Results)
data
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4408                                               None          1240259
# 4409  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4410  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4411  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4412  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           82585                                                 []
# 1           94540                                                 []
# 2          112960                                                 []
# 3          116766                                                 []
# 4          118017                                                 []
# ...           ...                                                ...
# 4408     28894436                                                 []
# 4409     29176245  [{'comments': None, 'relation': '=', 'result_f...
# 4410     29176246  [{'comments': None, 'relation': '=', 'result_f...
# 4411     29193884                                                 []
# 4412     29193885                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 1       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 2       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 3       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 4       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# ...              ...                                                ...
# 4408   CHEMBL5738928  Inhibition Assay: The compounds were tested fo...
# 4409   CHEMBL6110984  Inhibition of aromatase in human MCF7 cells us...
# 4410   CHEMBL6110984  Inhibition of aromatase in human MCF7 cells us...
# 4411   CHEMBL6116726           Inhibition of aromatase (unknown origin)
# 4412   CHEMBL6116726           Inhibition of aromatase (unknown origin)
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 4408          B                    None                   None  BAO_0000190
# 4409          B                    None                   None  BAO_0000190
# 4410          B                    None                   None  BAO_0000190
# 4411          B                    None                   None  BAO_0000190
# 4412          B                    None                   None  BAO_0000190
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens        Aromatase          9606       None  None
# 1     ...    Homo sapiens        Aromatase          9606       None  None
# 2     ...    Homo sapiens        Aromatase          9606       None  None
# 3     ...    Homo sapiens        Aromatase          9606       None  None
# 4     ...    Homo sapiens        Aromatase          9606       None  None
# ...   ...             ...              ...           ...        ...   ...
# 4408  ...    Homo sapiens        Aromatase          9606       None  None
# 4409  ...    Homo sapiens        Aromatase          9606       None  None
# 4410  ...    Homo sapiens        Aromatase          9606       None  None
# 4411  ...    Homo sapiens        Aromatase          9606       None  None
# 4412  ...    Homo sapiens        Aromatase          9606       None  None
#
#       type units    uo_units upper_value    value
# 0     IC50    uM  UO_0000065        None      7.1
# 1     IC50    uM  UO_0000065        None     50.0
# 2     IC50    uM  UO_0000065        None    0.238
# 3     IC50    uM  UO_0000065        None    0.057
# 4     IC50    uM  UO_0000065        None    0.054
# ...    ...   ...         ...         ...      ...
# 4408  IC50    nM  UO_0000065        None  14500.0
# 4409  IC50    nM  UO_0000065        None     64.9
# 4410  IC50    nM  UO_0000065        None   1850.0
# 4411  IC50    uM  UO_0000065        None      0.5
# 4412  IC50    uM  UO_0000065        None     45.0
#
# [4413 rows x 47 columns]

# %% [markdown]
# ## 1.2) Or Open CSV file from Google Drive

# %%
from google.colab import  drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Data.csv', sep =';')
data
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0            CHEMBL1397  POSACONAZOLE                 4.0            700.79
# 1          CHEMBL275594           NaN                 NaN            232.28
# 2          CHEMBL168444           NaN                 NaN            254.29
# 3          CHEMBL223452           NaN                 NaN            296.33
# 4          CHEMBL375043           NaN                 NaN            233.27
# ...                 ...           ...                 ...               ...
# 4408      CHEMBL5808901           NaN                 NaN            374.40
# 4409      CHEMBL5873947           NaN                 NaN            442.30
# 4410      CHEMBL5946526           NaN                 NaN            350.40
# 4411      CHEMBL6167931           NaN                 NaN            431.53
# 4412      CHEMBL5887888           NaN                 NaN            408.85
#
#       #RO5 Violations  AlogP  Compound Key  \
# 0                 2.0   4.57  Posaconazole
# 1                 0.0   1.56             7
# 2                 0.0   1.96             8
# 3                 0.0   3.40           T42
# 4                 0.0   2.96           T29
# ...               ...    ...           ...
# 4408              0.0   3.28    BDBM582683
# 4409              1.0   5.19    BDBM582675
# 4410              0.0   1.46    BDBM582666
# 4411              0.0   3.77            6a
# 4412              0.0   3.93    BDBM582699
#
#                                                  Smiles Standard Type  \
# 0     CC[C@@H]([C@H](C)O)n1ncn(-c2ccc(N3CCN(c4ccc(OC...          IC50
# 1                           CCCC1(c2ccncc2)CCC(=O)NC1=O          IC50
# 2                          O=C1c2ccccc2CCC1C(O)c1ccncn1          IC50
# 3                 N#Cc1ccc(C(c2ccc(C#N)cc2)c2cncnc2)cc1          IC50
# 4                           N#Cc1ccc(Cn2ccnc2)c2ccccc12          IC50
# ...                                                 ...           ...
# 4408       O=C1COc2cc(NCc3cccc(C(=O)Nc4cccnc4)c3)ccc2N1          IC50
# 4409  O=C1COc2cc(NCc3cccc(NC(=O)c4ccccc4Cl)c3)c(Cl)c...          IC50
# 4410          Cc1cccc(C(=O)OCCOc2ccc(S(N)(=O)=O)cc2)c1N          IC50
# 4411  CC(C)(C)c1ccc(S(=O)(=O)N2CCN(Cc3nc4cc(F)ccc4o3...          IC50
# 4412   O=C1COc2cc(NCc3cccc(C(=O)Nc4cccnc4)c3)c(Cl)cc2N1          IC50
#
#      Standard Relation  ...  Document ChEMBL ID Source ID  \
# 0                  '='  ...       CHEMBL4052712         1
# 1                  '='  ...       CHEMBL1123885         1
# 2                  '='  ...       CHEMBL1129578         1
# 3                  '='  ...       CHEMBL1139479         1
# 4                  '='  ...       CHEMBL1139479         1
# ...                ...  ...                 ...       ...
# 4408               '='  ...       CHEMBL5729535        37
# 4409               '>'  ...       CHEMBL5729535        37
# 4410               '='  ...       CHEMBL5729535        37
# 4411               '='  ...       CHEMBL6109100         1
# 4412               '='  ...       CHEMBL5729535        37
#
#                      Source Description      Document Journal Document Year  \
# 0                 Scientific Literature  Bioorg Med Chem Lett          2017
# 1                 Scientific Literature            J Med Chem          1987
# 2                 Scientific Literature            J Med Chem          1996
# 3                 Scientific Literature            J Med Chem          2005
# 4                 Scientific Literature            J Med Chem          2005
# ...                                 ...                   ...           ...
# 4408  BindingDB Patent Bioactivity Data                   NaN          2023
# 4409  BindingDB Patent Bioactivity Data                   NaN          2023
# 4410  BindingDB Patent Bioactivity Data                   NaN          2023
# 4411              Scientific Literature       Bioorg Med Chem          2025
# 4412  BindingDB Patent Bioactivity Data                   NaN          2023
#
#      Cell ChEMBL ID     Properties  Action Type  Standard Text Value     Value
# 0               NaN            NaN          NaN                  NaN      8.40
# 1               NaN            NaN          NaN                  NaN      6.00
# 2               NaN            NaN          NaN                  NaN     27.00
# 3               NaN            NaN          NaN                  NaN      6.54
# 4               NaN            NaN          NaN                  NaN      7.96
# ...             ...            ...          ...                  ...       ...
# 4408            NaN            NaN          NaN                  NaN   5700.00
# 4409            NaN            NaN          NaN                  NaN  25000.00
# 4410            NaN            NaN          NaN                  NaN  43500.00
# 4411            NaN  TIME = 2.0 hr    INHIBITOR                  NaN     64.90
# 4412            NaN            NaN          NaN                  NaN  14500.00
#
# [4413 rows x 48 columns]

# %%
data.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties',
#        'Action Type', 'Standard Text Value', 'Value'],
#       dtype='object')

# %% [markdown]
# # 2) Data Pre-processing

# %% [markdown]
# ## 2.1) Handling missing data

# %% [markdown]
# ### 2.1.1) Delete rows without standard value and SMILES

# %%
(data['standard_value'].notna()).value_counts()
# Utiliser cette instruction dans le cas de lecture du fichier CSV de Google Drive
#(data['Standard Value'].notna()).value_counts()
# Out:
# standard_value
# True     4319
# False      94
# Name: count, dtype: int64

# %%
(data['canonical_smiles'].notna()).value_counts()
# Utiliser cette instruction dans le cas de lecture du fichier CSV de Google Drive
#(data['Smiles'].notna()).value_counts()
# Out:
# canonical_smiles
# True    4413
# Name: count, dtype: int64

# %%
data2 = data[data['standard_value'].notna()]
data2 = data2[data2['canonical_smiles'].notna()]
# Utiliser ces instructiosn dans le cas de lecture du fichier CSV de Google Drive
#data2 = data[data['Standard Value'].notna()]
#data2 = data2[data2['Smiles'].notna()]
data2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4408                                               None          1240259
# 4409  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4410  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4411  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4412  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           82585                                                 []
# 1           94540                                                 []
# 2          112960                                                 []
# 3          116766                                                 []
# 4          118017                                                 []
# ...           ...                                                ...
# 4408     28894436                                                 []
# 4409     29176245  [{'comments': None, 'relation': '=', 'result_f...
# 4410     29176246  [{'comments': None, 'relation': '=', 'result_f...
# 4411     29193884                                                 []
# 4412     29193885                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 1       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 2       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 3       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 4       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# ...              ...                                                ...
# 4408   CHEMBL5738928  Inhibition Assay: The compounds were tested fo...
# 4409   CHEMBL6110984  Inhibition of aromatase in human MCF7 cells us...
# 4410   CHEMBL6110984  Inhibition of aromatase in human MCF7 cells us...
# 4411   CHEMBL6116726           Inhibition of aromatase (unknown origin)
# 4412   CHEMBL6116726           Inhibition of aromatase (unknown origin)
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 4408          B                    None                   None  BAO_0000190
# 4409          B                    None                   None  BAO_0000190
# 4410          B                    None                   None  BAO_0000190
# 4411          B                    None                   None  BAO_0000190
# 4412          B                    None                   None  BAO_0000190
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens        Aromatase          9606       None  None
# 1     ...    Homo sapiens        Aromatase          9606       None  None
# 2     ...    Homo sapiens        Aromatase          9606       None  None
# 3     ...    Homo sapiens        Aromatase          9606       None  None
# 4     ...    Homo sapiens        Aromatase          9606       None  None
# ...   ...             ...              ...           ...        ...   ...
# 4408  ...    Homo sapiens        Aromatase          9606       None  None
# 4409  ...    Homo sapiens        Aromatase          9606       None  None
# 4410  ...    Homo sapiens        Aromatase          9606       None  None
# 4411  ...    Homo sapiens        Aromatase          9606       None  None
# 4412  ...    Homo sapiens        Aromatase          9606       None  None
#
#       type units    uo_units upper_value    value
# 0     IC50    uM  UO_0000065        None      7.1
# 1     IC50    uM  UO_0000065        None     50.0
# 2     IC50    uM  UO_0000065        None    0.238
# 3     IC50    uM  UO_0000065        None    0.057
# 4     IC50    uM  UO_0000065        None    0.054
# ...    ...   ...         ...         ...      ...
# 4408  IC50    nM  UO_0000065        None  14500.0
# 4409  IC50    nM  UO_0000065        None     64.9
# 4410  IC50    nM  UO_0000065        None   1850.0
# 4411  IC50    uM  UO_0000065        None      0.5
# 4412  IC50    uM  UO_0000065        None     45.0
#
# [4319 rows x 47 columns]

# %%
data2.reset_index(drop = True, inplace = True)
data2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4314                                               None          1240259
# 4315  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4316  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4317  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4318  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           82585                                                 []
# 1           94540                                                 []
# 2          112960                                                 []
# 3          116766                                                 []
# 4          118017                                                 []
# ...           ...                                                ...
# 4314     28894436                                                 []
# 4315     29176245  [{'comments': None, 'relation': '=', 'result_f...
# 4316     29176246  [{'comments': None, 'relation': '=', 'result_f...
# 4317     29193884                                                 []
# 4318     29193885                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 1       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 2       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 3       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 4       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# ...              ...                                                ...
# 4314   CHEMBL5738928  Inhibition Assay: The compounds were tested fo...
# 4315   CHEMBL6110984  Inhibition of aromatase in human MCF7 cells us...
# 4316   CHEMBL6110984  Inhibition of aromatase in human MCF7 cells us...
# 4317   CHEMBL6116726           Inhibition of aromatase (unknown origin)
# 4318   CHEMBL6116726           Inhibition of aromatase (unknown origin)
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 4314          B                    None                   None  BAO_0000190
# 4315          B                    None                   None  BAO_0000190
# 4316          B                    None                   None  BAO_0000190
# 4317          B                    None                   None  BAO_0000190
# 4318          B                    None                   None  BAO_0000190
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens        Aromatase          9606       None  None
# 1     ...    Homo sapiens        Aromatase          9606       None  None
# 2     ...    Homo sapiens        Aromatase          9606       None  None
# 3     ...    Homo sapiens        Aromatase          9606       None  None
# 4     ...    Homo sapiens        Aromatase          9606       None  None
# ...   ...             ...              ...           ...        ...   ...
# 4314  ...    Homo sapiens        Aromatase          9606       None  None
# 4315  ...    Homo sapiens        Aromatase          9606       None  None
# 4316  ...    Homo sapiens        Aromatase          9606       None  None
# 4317  ...    Homo sapiens        Aromatase          9606       None  None
# 4318  ...    Homo sapiens        Aromatase          9606       None  None
#
#       type units    uo_units upper_value    value
# 0     IC50    uM  UO_0000065        None      7.1
# 1     IC50    uM  UO_0000065        None     50.0
# 2     IC50    uM  UO_0000065        None    0.238
# 3     IC50    uM  UO_0000065        None    0.057
# 4     IC50    uM  UO_0000065        None    0.054
# ...    ...   ...         ...         ...      ...
# 4314  IC50    nM  UO_0000065        None  14500.0
# 4315  IC50    nM  UO_0000065        None     64.9
# 4316  IC50    nM  UO_0000065        None   1850.0
# 4317  IC50    uM  UO_0000065        None      0.5
# 4318  IC50    uM  UO_0000065        None     45.0
#
# [4319 rows x 47 columns]

# %% [markdown]
# ## 2.2) Delete duplicated SMILES

# %%
len(data2.canonical_smiles.unique())
# Utiliser cette instruction dans le cas de lecture du fichier CSV de Google Drive
#len(data2.Smiles.unique())
# Out:
# 3130

# %%
data3 = data2.drop_duplicates('canonical_smiles')
# Utiliser cette instruction dans le cas de lecture du fichier CSV de Google Drive
#data3 = data2.drop_duplicates('Smiles')
data3.reset_index(drop = True, inplace = True)
data3
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 3125                                               None          1240239
# 3126                                               None          1240245
# 3127                                               None          1240252
# 3128                                               None          1240259
# 3129  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           82585                                                 []
# 1           94540                                                 []
# 2          112960                                                 []
# 3          116766                                                 []
# 4          118017                                                 []
# ...           ...                                                ...
# 3125     28894376                                                 []
# 3126     28894394                                                 []
# 3127     28894415                                                 []
# 3128     28894436                                                 []
# 3129     29176245  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 1       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 2       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 3       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 4       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# ...              ...                                                ...
# 3125   CHEMBL5738928  Inhibition Assay: The compounds were tested fo...
# 3126   CHEMBL5738928  Inhibition Assay: The compounds were tested fo...
# 3127   CHEMBL5738928  Inhibition Assay: The compounds were tested fo...
# 3128   CHEMBL5738928  Inhibition Assay: The compounds were tested fo...
# 3129   CHEMBL6110984  Inhibition of aromatase in human MCF7 cells us...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 3125          B                    None                   None  BAO_0000190
# 3126          B                    None                   None  BAO_0000190
# 3127          B                    None                   None  BAO_0000190
# 3128          B                    None                   None  BAO_0000190
# 3129          B                    None                   None  BAO_0000190
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens        Aromatase          9606       None  None
# 1     ...    Homo sapiens        Aromatase          9606       None  None
# 2     ...    Homo sapiens        Aromatase          9606       None  None
# 3     ...    Homo sapiens        Aromatase          9606       None  None
# 4     ...    Homo sapiens        Aromatase          9606       None  None
# ...   ...             ...              ...           ...        ...   ...
# 3125  ...    Homo sapiens        Aromatase          9606       None  None
# 3126  ...    Homo sapiens        Aromatase          9606       None  None
# 3127  ...    Homo sapiens        Aromatase          9606       None  None
# 3128  ...    Homo sapiens        Aromatase          9606       None  None
# 3129  ...    Homo sapiens        Aromatase          9606       None  None
#
#       type units    uo_units upper_value    value
# 0     IC50    uM  UO_0000065        None      7.1
# 1     IC50    uM  UO_0000065        None     50.0
# 2     IC50    uM  UO_0000065        None    0.238
# 3     IC50    uM  UO_0000065        None    0.057
# 4     IC50    uM  UO_0000065        None    0.054
# ...    ...   ...         ...         ...      ...
# 3125  IC50    nM  UO_0000065        None   5700.0
# 3126  IC50    nM  UO_0000065        None   8600.0
# 3127  IC50    nM  UO_0000065        None     60.0
# 3128  IC50    nM  UO_0000065        None  14500.0
# 3129  IC50    nM  UO_0000065        None     64.9
#
# [3130 rows x 47 columns]

# %% [markdown]
# ## 2.3) Select 3 columns : ID, SMILES and IC50

# %%
data3.columns
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'modality', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %%
selected_columns = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
# Utiliser cette instruction dans le cas de lecture du fichier CSV de Google Drive
#selected_columns = ['Molecule ChEMBL ID', 'Smiles', 'Standard Value']
data4 = data3[selected_columns]
data4
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL341591          CC12CCC(O)CC1=CCC1C2CCC2(C)C(CC3CN3)CCC12
# 1         CHEMBL2111947  C[C@]12CC[C@H]3[C@@H](CC=C4C[C@@H](O)CC[C@@]43...
# 2          CHEMBL431859      CCn1c(C(c2ccc(F)cc2)n2ccnc2)c(C)c2cc(Br)ccc21
# 3          CHEMBL113637             CCn1cc(C(c2ccc(F)cc2)n2ccnc2)c2ccccc21
# 4          CHEMBL112021                 Clc1ccccc1Cn1cc(Cn2ccnc2)c2ccccc21
# ...                 ...                                                ...
# 3125      CHEMBL5808901       O=C1COc2cc(NCc3cccc(C(=O)Nc4cccnc4)c3)ccc2N1
# 3126      CHEMBL5916153      O=C1COc2cc(NCc3cccc(C(=O)Nc4ccccc4O)c3)ccc2N1
# 3127      CHEMBL5875159  O=C1COc2cc(NC(=O)c3cc(NC(=O)c4cn[nH]c4)ccc3Cl)...
# 3128      CHEMBL5887888   O=C1COc2cc(NCc3cccc(C(=O)Nc4cccnc4)c3)c(Cl)cc2N1
# 3129      CHEMBL6167931  CC(C)(C)c1ccc(S(=O)(=O)N2CCN(Cc3nc4cc(F)ccc4o3...
#
#      standard_value
# 0            7100.0
# 1           50000.0
# 2             238.0
# 3              57.0
# 4              54.0
# ...             ...
# 3125         5700.0
# 3126         8600.0
# 3127           60.0
# 3128        14500.0
# 3129           64.9
#
# [3130 rows x 3 columns]

# %%
data4.rename(columns = {'standard_value':'IC50', 'molecule_chembl_id':'ID', 'canonical_smiles':'SMILES'}, inplace = True)
# Utiliser cette instruction dans le cas de lecture du fichier CSV de Google Drive
#data4.rename(columns = {'Standard Value':'IC50', 'Molecule ChEMBL ID':'ID'}, inplace = True)
data4
# Out:
# /tmp/ipykernel_3236/270839843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4.rename(columns = {'standard_value':'IC50', 'molecule_chembl_id':'ID', 'canonical_smiles':'SMILES'}, inplace = True)
#                  ID                                             SMILES  \
# 0      CHEMBL341591          CC12CCC(O)CC1=CCC1C2CCC2(C)C(CC3CN3)CCC12
# 1     CHEMBL2111947  C[C@]12CC[C@H]3[C@@H](CC=C4C[C@@H](O)CC[C@@]43...
# 2      CHEMBL431859      CCn1c(C(c2ccc(F)cc2)n2ccnc2)c(C)c2cc(Br)ccc21
# 3      CHEMBL113637             CCn1cc(C(c2ccc(F)cc2)n2ccnc2)c2ccccc21
# 4      CHEMBL112021                 Clc1ccccc1Cn1cc(Cn2ccnc2)c2ccccc21
# ...             ...                                                ...
# 3125  CHEMBL5808901       O=C1COc2cc(NCc3cccc(C(=O)Nc4cccnc4)c3)ccc2N1
# 3126  CHEMBL5916153      O=C1COc2cc(NCc3cccc(C(=O)Nc4ccccc4O)c3)ccc2N1
# 3127  CHEMBL5875159  O=C1COc2cc(NC(=O)c3cc(NC(=O)c4cn[nH]c4)ccc3Cl)...
# 3128  CHEMBL5887888   O=C1COc2cc(NCc3cccc(C(=O)Nc4cccnc4)c3)c(Cl)cc2N1
# 3129  CHEMBL6167931  CC(C)(C)c1ccc(S(=O)(=O)N2CCN(Cc3nc4cc(F)ccc4o3...
#
#          IC50
# 0      7100.0
# 1     50000.0
# 2       238.0
# 3        57.0
# 4        54.0
# ...       ...
# 3125   5700.0
# 3126   8600.0
# 3127     60.0
# 3128  14500.0
# 3129     64.9
#
# [3130 rows x 3 columns]

# %%
data4.info()

# %%
data4 = data4.convert_dtypes()
data4.info()

# %%
data4['IC50'] = data4['IC50'].astype(float)
data4.info()

# %%
(data4['IC50'] == 0).value_counts()

# %%
data4['IC50'].describe()

# %%
data5 = data4[data4['IC50'] != 0]
data5.reset_index(drop = True, inplace = True)
data5

# %% [markdown]
# ## 2.4) Calculate pIC50

# %%
def pIC50(DF):
  p_values = []
  for i in DF['IC50']:
    if i > 100000000:
      i = 100000000
    molar = i * (10 ** -9)
    p = -np.log10(molar)
    p_values.append(p)
  DF['pIC50'] = p_values
  DF2 = DF.drop('IC50', axis = 1)
  return DF2

# %%
data6 = pIC50(data5)
data6

# %%
data6['pIC50'].describe()

# %% [markdown]
# # 3) Exploratory Data Analysis

# %% [markdown]
# ## 3.1) Install RDKIT Library

# %%
# !pip install rdkit

# %% [markdown]
# ## 3.2) Import modules from RDKIT library

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %% [markdown]
# ## 3.3) Calculate Lipinski descriptors

# %%
def lipinski(smiles):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem)
        moldata.append(mol)

    baseData= np.arange(1,1)
    i=0
    for mol in moldata:

        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)

        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])

        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1

    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)

    return descriptors

# %%
Smiles = data6['SMILES']
Lipinski_Descriptors = lipinski(Smiles)
Lipinski_Descriptors

# %%
data_combined = pd.concat([data6, Lipinski_Descriptors], axis=1)
data_combined

# %%
data_combined.pIC50.describe()

# %%
Activity = []
for p in data_combined['pIC50']:
  if p >= 6:
    Activity.append('Active')
  else:
    Activity.append('Inactive')
data_combined['Class'] = Activity
data_combined

# %% [markdown]
# ## 3.4) Generate plots

# %% [markdown]
# ### 3.4.1) Histograms

# %%
p_values = np.array(data_combined['pIC50'])
n, bin, patches = plt.hist(p_values, 50, density = True,
                           facecolor = 'g', alpha = 0.75)
plt.xlabel('pIC50 values')
plt.ylabel('Molecules number')
plt.title('Histogram of pIC50')
plt.grid(True)
plt.show()

# %%
sns.countplot(data = data_combined, x = 'Class')
plt.xlabel('Class')
plt.ylabel('Molecules number')
plt.title('Histrogram of Activity Class')
plt.show()

# %%
data_combined['Class'].value_counts()

# %% [markdown]
# ### 3.4.2) Boxplots

# %%
sns.boxplot(x = data_combined['Class'], y = data_combined['MW'])
plt.title("Boxplot on Molecular Weight")
plt.show()

# %%
sns.boxplot(x = data_combined['Class'], y = data_combined['LogP'])
plt.title("Boxplot on LogP")
plt.show()

# %%
sns.boxplot(x = data_combined['Class'], y = data_combined['NumHDonors'])
plt.title("Boxplot on NumHDonors")
plt.show()

# %%
sns.boxplot(x = data_combined['Class'], y = data_combined['NumHAcceptors'])
plt.title("Boxplot on NumHAcceptors")
plt.show()

# %% [markdown]
# ### 3.4.3) Scatterplot

# %%
g = sns.scatterplot(data = data_combined, x = 'MW', y = 'LogP',
                    hue = 'Class', size = 'pIC50')
sns.move_legend(g, 'upper left',
                bbox_to_anchor = (1, 1), title = 'Class')
plt.title("Scatterplot on Molecular Weight and LogP")
plt.show()

# %% [markdown]
# ## 3.5) Statistical Test (nonparametric test : Mann-Whitney U Test)

# %%
def mannwhitney(descriptor):
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'Class']
  df14 = data_combined[selection]

  active = df14[df14['Class'] == 'Active']
  active = active[descriptor]

  inactive = df14[df14['Class'] == 'Inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'

  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')

# %%
mannwhitney('MW')

# %%
mannwhitney('LogP')

# %%
mannwhitney('NumHDonors')

# %%
mannwhitney('NumHAcceptors')

# %% [markdown]
# # 4) Descriptors Generation

# %% [markdown]
# ## 4.1) Install PADELPy Library

# %%
# !pip install padelpy

# %%
# Download fingerprint XML files
! wget https://github.com/dataprofessor/padel/raw/main/fingerprints_xml.zip
! unzip fingerprints_xml.zip

# %%
# List and sort fingerprint XML files
import glob
xml_files = glob.glob("*.xml")
xml_files.sort()
xml_files

FP_list = ['AtomPairs2DCount',
 'AtomPairs2D',
 'EState',
 'CDKextended',
 'CDK',
 'CDKgraphonly',
 'KlekotaRothCount',
 'KlekotaRoth',
 'MACCS',
 'PubChem',
 'SubstructureCount',
 'Substructure']

# Create a dictionary
fp = dict(zip(FP_list, xml_files))

df = pd.concat([data_combined['SMILES'], data_combined['ID']], axis=1 )
df.to_csv('molecules.smi', sep='\t', index=False, header=False)
df

# %% [markdown]
# ## 4.2) Generate Fingerprints

# %%
# To fix the Java JRE 6+ not found error, run this command line
# !apt-get install -y openjdk-11-jre-headless

# %%
from padelpy import padeldescriptor
padeldescriptor(mol_dir = "molecules.smi",
             d_file = 'PubChem_descriptors.csv',
             descriptortypes = fp['PubChem'],
             detectaromaticity = True,
             standardizetautomers = True,
             threads = 2,
             removesalt = True,
             log = True,
             fingerprints = True)

# %%
Descriptors = pd.read_csv('PubChem_descriptors.csv')
Descriptors

# %%
Descriptors.drop("Name", axis = 1 , inplace = True)
Descriptors

# %% [markdown]
# # 5) Feature Selection

# %%
from sklearn.feature_selection  import VarianceThreshold
selection = VarianceThreshold(threshold = (0.8 * (1 - 0.8)))
X = selection.fit_transform(Descriptors)
X

# %%
Y = data_combined['pIC50']
Y

# %% [markdown]
# # 6) Model Training

# %% [markdown]
# ## 6.1) Split the dataset into Train/Test sets

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, train_size = 0.8,
                                                    test_size = 0.2)

# %%
X.shape, Y.shape

# %%
X_Train.shape, Y_Train.shape

# %%
X_Test.shape, Y_Test.shape

# %% [markdown]
# ## 6.2) Train the model

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 10)
model.fit(X_Train, Y_Train)

# %%
Y_Pred = model.predict(X_Test)
Y_Pred

# %% [markdown]
# # 7) Model Evaluation

# %%
from sklearn import metrics

# %%
R2 = metrics.r2_score(Y_Test, Y_Pred)
MSE = metrics.mean_squared_error(Y_Test, Y_Pred)
RMSE = np.sqrt(MSE)
MAE = metrics.mean_absolute_error(Y_Test, Y_Pred)
MAPE = metrics.mean_absolute_percentage_error(Y_Test, Y_Pred)
Max_Error = metrics.max_error(Y_Test, Y_Pred)
print("R2 = ", round(R2, 3))
print("MSE = ", round(MSE, 3))
print("RMSE = ", round(RMSE, 3))
print("MAE = ", round(MAE, 3))
print("MAPE = ", round(MAPE, 3))
print("Max_Error = ", round(Max_Error, 3))

# %%
sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(x= Y_Test, y = Y_Pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show()

# %% [markdown]
# # 8) Feature Importance

# %%
mask = selection.get_support()
selected_columns_indices = [i for i, f in enumerate(mask) if f]
features = Descriptors.columns[selected_columns_indices]
features

# %%
features.shape , len(selected_columns_indices)

# %%
importances = model.feature_importances_
best_indices = np.argsort(importances)[-5:]
worst_indices = np.argsort(importances)[:5]
indices = np.concatenate([worst_indices, best_indices])

plt.figure(figsize=(10,8))
plt.title('10 Most and 10 Least Important Features in the Model')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.ylabel('Feature Name')
plt.show()
